# %%
import numpy as np
import matplotlib.pyplot as plt 
  
# Using exponential() method 
Vector = np.random.exponential(0.1, 100) 
Vector_lst = []
for i in range(0,1000):
    Vector = np.random.exponential(0.1, 100)
    Vector_lst.append(Vector)
naxi = -float('inf')
maxCoord= None
for i,row in enumareate(Vector_lst):
    forj, col in enumrate(row)
# Out:
# 1.1745316256312597
# 1.1745316256312597

# %%
Vector_all = []
for i ina
